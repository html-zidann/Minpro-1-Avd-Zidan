# %% [markdown]
# https://www.kaggle.com/datasets/teajay/global-shark-attacks

# %%
import numpy as np

# %%
import seaborn as sns

# %%
import matplotlib.pyplot as plt

# %%
import pandas as pd

# %% [markdown]
# # **DATASET PENYERANGAN HIU SKALA GLOBAL**

# %%
file_path = '/content/attacks.csv'

df = pd.read_csv(file_path, encoding='latin-1')
df
# Out:
#       Case Number         Date    Year        Type    Country  \
# 0      2018.06.25  25-Jun-2018  2018.0     Boating        USA
# 1      2018.06.18  18-Jun-2018  2018.0  Unprovoked        USA
# 2      2018.06.09  09-Jun-2018  2018.0     Invalid        USA
# 3      2018.06.08  08-Jun-2018  2018.0  Unprovoked  AUSTRALIA
# 4      2018.06.04  04-Jun-2018  2018.0    Provoked     MEXICO
# ...           ...          ...     ...         ...        ...
# 25718         NaN          NaN     NaN         NaN        NaN
# 25719         NaN          NaN     NaN         NaN        NaN
# 25720         NaN          NaN     NaN         NaN        NaN
# 25721         NaN          NaN     NaN         NaN        NaN
# 25722          xx          NaN     NaN         NaN        NaN
#
#                   Area                        Location     Activity  \
# 0           California     Oceanside, San Diego County     Paddling
# 1              Georgia  St. Simon Island, Glynn County     Standing
# ...

# %%
df.head()
# Out:
#   Case Number         Date    Year        Type    Country             Area  \
# 0  2018.06.25  25-Jun-2018  2018.0     Boating        USA       California
# 1  2018.06.18  18-Jun-2018  2018.0  Unprovoked        USA          Georgia
# 2  2018.06.09  09-Jun-2018  2018.0     Invalid        USA           Hawaii
# 3  2018.06.08  08-Jun-2018  2018.0  Unprovoked  AUSTRALIA  New South Wales
# 4  2018.06.04  04-Jun-2018  2018.0    Provoked     MEXICO           Colima
#
#                          Location     Activity             Name Sex   ...  \
# 0     Oceanside, San Diego County     Paddling      Julie Wolfe    F  ...
# 1  St. Simon Island, Glynn County     Standing  Adyson McNeely     F  ...
# 2                    Habush, Oahu      Surfing      John Denges    M  ...
# 3              Arrawarra Headland      Surfing             male    M  ...
# 4                        La Ticla  Free diving   Gustavo Ramos     M  ...
#
# ...

# %%
df.tail()
# Out:
#       Case Number Date  Year Type Country Area Location Activity Name Sex   \
# 25718         NaN  NaN   NaN  NaN     NaN  NaN      NaN      NaN  NaN  NaN
# 25719         NaN  NaN   NaN  NaN     NaN  NaN      NaN      NaN  NaN  NaN
# 25720         NaN  NaN   NaN  NaN     NaN  NaN      NaN      NaN  NaN  NaN
# 25721         NaN  NaN   NaN  NaN     NaN  NaN      NaN      NaN  NaN  NaN
# 25722          xx  NaN   NaN  NaN     NaN  NaN      NaN      NaN  NaN  NaN
#
#        ... Species  Investigator or Source  pdf href formula href  \
# 25718  ...      NaN                    NaN  NaN          NaN  NaN
# 25719  ...      NaN                    NaN  NaN          NaN  NaN
# 25720  ...      NaN                    NaN  NaN          NaN  NaN
# 25721  ...      NaN                    NaN  NaN          NaN  NaN
# 25722  ...      NaN                    NaN  NaN          NaN  NaN
#
#       Case Number.1 Case Number.2 original order Unnamed: 22 Unnamed: 23
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25723 entries, 0 to 25722
# Data columns (total 24 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Case Number             8702 non-null   object
#  1   Date                    6302 non-null   object
#  2   Year                    6300 non-null   float64
#  3   Type                    6298 non-null   object
#  4   Country                 6252 non-null   object
#  5   Area                    5847 non-null   object
#  6   Location                5762 non-null   object
#  7   Activity                5758 non-null   object
#  8   Name                    6092 non-null   object
#  9   Sex                     5737 non-null   object
#  10  Age                     3471 non-null   object
#  11  Injury                  6274 non-null   object
#  12  Fatal (Y/N)             5763 non-null   object
#  13  Time                    2948 non-null   object
# ...

# %%
df.shape
# Out:
# (25723, 24)

# %%
df.dtypes
# Out:
# Case Number                object
# Date                       object
# Year                      float64
# Type                       object
# Country                    object
# Area                       object
# Location                   object
# Activity                   object
# Name                       object
# Sex                        object
# Age                        object
# Injury                     object
# Fatal (Y/N)                object
# Time                       object
# Species                    object
# Investigator or Source     object
# pdf                        object
# href formula               object
# href                       object
# Case Number.1              object
# Case Number.2              object
# original order            float64
# Unnamed: 22                object
# Unnamed: 23                object
# dtype: object

# %%
df.describe()
# Out:
#               Year  original order
# count  6300.000000     6309.000000
# mean   1927.272381     3155.999683
# std     281.116308     1821.396206
# min       0.000000        2.000000
# 25%    1942.000000     1579.000000
# 50%    1977.000000     3156.000000
# 75%    2005.000000     4733.000000
# max    2018.000000     6310.000000

# %%
print(df.corr(numeric_only=True))
# Out:
#                     Year  original order
# Year            1.000000        0.388638
# original order  0.388638        1.000000

# %%
print((df.isna().sum() / len(df)) * 100)
# Out:
# Case Number               66.170353
# Date                      75.500525
# Year                      75.508300
# Type                      75.516075
# Country                   75.694903
# Area                      77.269370
# Location                  77.599813
# Activity                  77.615364
# Name                      76.316915
# Sex                       77.697003
# Age                       86.506240
# Injury                    75.609377
# Fatal (Y/N)               77.595926
# Time                      88.539439
# Species                   86.533453
# Investigator or Source    75.566614
# pdf                       75.500525
# href formula              75.504412
# href                      75.500525
# Case Number.1             75.500525
# Case Number.2             75.500525
# original order            75.473312
# Unnamed: 22               99.996112
# Unnamed: 23               99.992225
# dtype: float64

# %%
df[df['Unnamed: 22'].isnull()]
# Out:
#       Case Number         Date    Year        Type    Country  \
# 0      2018.06.25  25-Jun-2018  2018.0     Boating        USA
# 1      2018.06.18  18-Jun-2018  2018.0  Unprovoked        USA
# 2      2018.06.09  09-Jun-2018  2018.0     Invalid        USA
# 3      2018.06.08  08-Jun-2018  2018.0  Unprovoked  AUSTRALIA
# 4      2018.06.04  04-Jun-2018  2018.0    Provoked     MEXICO
# ...           ...          ...     ...         ...        ...
# 25718         NaN          NaN     NaN         NaN        NaN
# 25719         NaN          NaN     NaN         NaN        NaN
# 25720         NaN          NaN     NaN         NaN        NaN
# 25721         NaN          NaN     NaN         NaN        NaN
# 25722          xx          NaN     NaN         NaN        NaN
#
#                   Area                        Location     Activity  \
# 0           California     Oceanside, San Diego County     Paddling
# 1              Georgia  St. Simon Island, Glynn County     Standing
# ...

# %%
df[df['Unnamed: 23'].isnull()]
# Out:
#       Case Number         Date    Year        Type    Country  \
# 0      2018.06.25  25-Jun-2018  2018.0     Boating        USA
# 1      2018.06.18  18-Jun-2018  2018.0  Unprovoked        USA
# 2      2018.06.09  09-Jun-2018  2018.0     Invalid        USA
# 3      2018.06.08  08-Jun-2018  2018.0  Unprovoked  AUSTRALIA
# 4      2018.06.04  04-Jun-2018  2018.0    Provoked     MEXICO
# ...           ...          ...     ...         ...        ...
# 25718         NaN          NaN     NaN         NaN        NaN
# 25719         NaN          NaN     NaN         NaN        NaN
# 25720         NaN          NaN     NaN         NaN        NaN
# 25721         NaN          NaN     NaN         NaN        NaN
# 25722          xx          NaN     NaN         NaN        NaN
#
#                   Area                        Location     Activity  \
# 0           California     Oceanside, San Diego County     Paddling
# 1              Georgia  St. Simon Island, Glynn County     Standing
# ...

# %%
df['Unnamed: 22'].dropna().describe()
# Out:
# count                1
# unique               1
# top       stopped here
# freq                 1
# Name: Unnamed: 22, dtype: object

# %%
df['Unnamed: 23'].dropna().describe()
# Out:
# count          2
# unique         2
# top       Teramo
# freq           1
# Name: Unnamed: 23, dtype: object

# %% [markdown]
# disini saya langsung drop data yang non numeric

# %%
df['Unnamed: 22'] = pd.to_numeric(df['Unnamed: 22'], errors='coerce')
df['Unnamed: 22'] = df['Unnamed: 22'].fillna(df['Unnamed: 22'].dropna().mean())

# %%
df['Unnamed: 23'] = pd.to_numeric(df['Unnamed: 23'], errors='coerce')
df['Unnamed: 23'] = df['Unnamed: 23'].fillna(df['Unnamed: 23'].dropna().mean())

# %%
df[df.duplicated()]
# Out:
#       Case Number Date  Year Type Country Area Location Activity Name Sex   \
# 6310            0  NaN   NaN  NaN     NaN  NaN      NaN      NaN  NaN  NaN
# 6311            0  NaN   NaN  NaN     NaN  NaN      NaN      NaN  NaN  NaN
# 6312            0  NaN   NaN  NaN     NaN  NaN      NaN      NaN  NaN  NaN
# 6313            0  NaN   NaN  NaN     NaN  NaN      NaN      NaN  NaN  NaN
# 6314            0  NaN   NaN  NaN     NaN  NaN      NaN      NaN  NaN  NaN
# ...           ...  ...   ...  ...     ...  ...      ...      ...  ...  ...
# 25717         NaN  NaN   NaN  NaN     NaN  NaN      NaN      NaN  NaN  NaN
# 25718         NaN  NaN   NaN  NaN     NaN  NaN      NaN      NaN  NaN  NaN
# 25719         NaN  NaN   NaN  NaN     NaN  NaN      NaN      NaN  NaN  NaN
# 25720         NaN  NaN   NaN  NaN     NaN  NaN      NaN      NaN  NaN  NaN
# 25721         NaN  NaN   NaN  NaN     NaN  NaN      NaN      NaN  NaN  NaN
#
#        ... Species  Investigator or Source  pdf href formula href  \
# ...

# %%
df = df.drop_duplicates()

# %%
df
# Out:
#       Case Number         Date    Year        Type    Country  \
# 0      2018.06.25  25-Jun-2018  2018.0     Boating        USA
# 1      2018.06.18  18-Jun-2018  2018.0  Unprovoked        USA
# 2      2018.06.09  09-Jun-2018  2018.0     Invalid        USA
# 3      2018.06.08  08-Jun-2018  2018.0  Unprovoked  AUSTRALIA
# 4      2018.06.04  04-Jun-2018  2018.0    Provoked     MEXICO
# ...           ...          ...     ...         ...        ...
# 6307            0          NaN     NaN         NaN        NaN
# 6308            0          NaN     NaN         NaN        NaN
# 6309            0          NaN     NaN         NaN        NaN
# 8702          NaN          NaN     NaN         NaN        NaN
# 25722          xx          NaN     NaN         NaN        NaN
#
#                   Area                        Location     Activity  \
# 0           California     Oceanside, San Diego County     Paddling
# 1              Georgia  St. Simon Island, Glynn County     Standing
# ...

# %%
results = []

cols = df.select_dtypes(include=['float64', 'int64'])

for col in cols:
  q1 = df[col].quantile(0.25)
  q3 = df[col].quantile(0.75)
  iqr = q3 - q1
  lower_bound = q1 - 1.5*iqr
  upper_bound = q3 + 1.5*iqr
  outliers = df[(df[col] < lower_bound) | (df[col] > upper_bound)]
  percent_outliers = (len(outliers)/len(df))*100
  results.append({'Kolom': col, 'Persentase Outliers': percent_outliers})

# Dataframe dari list hasil
results_df = pd.DataFrame(results)
results_df.set_index('Kolom', inplace=True)
results_df = results_df.rename_axis(None, axis=0).rename_axis('Kolom', axis=1)

# Tampilkan dataframe
display(results_df)
# Out:
# Kolom           Persentase Outliers
# Year                       4.134981
# original order             0.000000
# Unnamed: 22                0.000000
# Unnamed: 23                0.000000

# %%
columns_to_impute = ["Case Number", "Date", "Year", "Type", "Country", "Area", "Location", "Activity", "Name", "Sex", "...", "Species", "Investigator or Source", "pdf", "href formula\t", "href", "Case Number.1", "Case Number.2", "original order", "Unnamed: 22", "Unnamed: 23"]

for col in columns_to_impute:
    # Check if the column exists in the DataFrame
    if col in df.columns:
        # Check if the column is numeric
        if pd.api.types.is_numeric_dtype(df[col]):
            Q1 = df[col].quantile(0.25)
            Q3 = df[col].quantile(0.75)
            IQR = Q3 - Q1
            lower_bound = Q1 - 1.5 * IQR
            upper_bound = Q3 + 1.5 * IQR

            # Using .loc[] to avoid SettingWithCopyWarning
            df.loc[:, col] = df[col].clip(lower=lower_bound, upper=upper_bound)
        else:
            print(f"Column '{col}' is not numeric. Skipping outlier handling...") # Print a message if the column is not numeric
    else:
        print(f"Column '{col}' not found in DataFrame. Skipping...") # Print a warning message if the column is not found
# Out:
# Column 'Case Number' is not numeric. Skipping outlier handling...
# Column 'Date' is not numeric. Skipping outlier handling...
# Column 'Type' is not numeric. Skipping outlier handling...
# Column 'Country' is not numeric. Skipping outlier handling...
# Column 'Area' is not numeric. Skipping outlier handling...
# Column 'Location' is not numeric. Skipping outlier handling...
# Column 'Activity' is not numeric. Skipping outlier handling...
# Column 'Name' is not numeric. Skipping outlier handling...
# Column 'Sex' not found in DataFrame. Skipping...
# Column '...' not found in DataFrame. Skipping...
# Column 'Species' not found in DataFrame. Skipping...
# Column 'Investigator or Source' is not numeric. Skipping outlier handling...
# Column 'pdf' is not numeric. Skipping outlier handling...
# Column 'href formula	' not found in DataFrame. Skipping...
# Column 'href' is not numeric. Skipping outlier handling...
# Column 'Case Number.1' is not numeric. Skipping outlier handling...
# ...

# %%
results = []

cols = df.select_dtypes(include=['float64', 'int64'])

for col in cols:
  q1 = df[col].quantile(0.25)
  q3 = df[col].quantile(0.75)
  iqr = q3 - q1
  lower_bound = q1 - 1.5*iqr
  upper_bound = q3 + 1.5*iqr
  outliers = df[(df[col] < lower_bound) | (df[col] > upper_bound)]
  percent_outliers = (len(outliers)/len(df))*100
  results.append({'Kolom': col, 'Persentase Outliers': percent_outliers})

# Dataframe dari list hasil
results_df = pd.DataFrame(results)
results_df.set_index('Kolom', inplace=True)
results_df = results_df.rename_axis(None, axis=0).rename_axis('Kolom', axis=1)

# Tampilkan dataframe
display(results_df)
# Out:
# Kolom           Persentase Outliers
# Year                            0.0
# original order                  0.0
# Unnamed: 22                     0.0
# Unnamed: 23                     0.0

# %%
df
# Out:
#       Case Number         Date    Year        Type    Country  \
# 0      2018.06.25  25-Jun-2018  2018.0     Boating        USA
# 1      2018.06.18  18-Jun-2018  2018.0  Unprovoked        USA
# 2      2018.06.09  09-Jun-2018  2018.0     Invalid        USA
# 3      2018.06.08  08-Jun-2018  2018.0  Unprovoked  AUSTRALIA
# 4      2018.06.04  04-Jun-2018  2018.0    Provoked     MEXICO
# ...           ...          ...     ...         ...        ...
# 6307            0          NaN     NaN         NaN        NaN
# 6308            0          NaN     NaN         NaN        NaN
# 6309            0          NaN     NaN         NaN        NaN
# 8702          NaN          NaN     NaN         NaN        NaN
# 25722          xx          NaN     NaN         NaN        NaN
#
#                   Area                        Location     Activity  \
# 0           California     Oceanside, San Diego County     Paddling
# 1              Georgia  St. Simon Island, Glynn County     Standing
# ...

# %%
df = df.drop('Unnamed: 22', axis=1)

# %%
df
# Out:
#       Case Number         Date    Year        Type    Country  \
# 0      2018.06.25  25-Jun-2018  2018.0     Boating        USA
# 1      2018.06.18  18-Jun-2018  2018.0  Unprovoked        USA
# 2      2018.06.09  09-Jun-2018  2018.0     Invalid        USA
# 3      2018.06.08  08-Jun-2018  2018.0  Unprovoked  AUSTRALIA
# 4      2018.06.04  04-Jun-2018  2018.0    Provoked     MEXICO
# ...           ...          ...     ...         ...        ...
# 6307            0          NaN     NaN         NaN        NaN
# 6308            0          NaN     NaN         NaN        NaN
# 6309            0          NaN     NaN         NaN        NaN
# 8702          NaN          NaN     NaN         NaN        NaN
# 25722          xx          NaN     NaN         NaN        NaN
#
#                   Area                        Location     Activity  \
# 0           California     Oceanside, San Diego County     Paddling
# 1              Georgia  St. Simon Island, Glynn County     Standing
# ...

# %%
df = df.drop('Unnamed: 23', axis=1)

# %%
df
# Out:
#       Case Number         Date    Year        Type    Country  \
# 0      2018.06.25  25-Jun-2018  2018.0     Boating        USA
# 1      2018.06.18  18-Jun-2018  2018.0  Unprovoked        USA
# 2      2018.06.09  09-Jun-2018  2018.0     Invalid        USA
# 3      2018.06.08  08-Jun-2018  2018.0  Unprovoked  AUSTRALIA
# 4      2018.06.04  04-Jun-2018  2018.0    Provoked     MEXICO
# ...           ...          ...     ...         ...        ...
# 6307            0          NaN     NaN         NaN        NaN
# 6308            0          NaN     NaN         NaN        NaN
# 6309            0          NaN     NaN         NaN        NaN
# 8702          NaN          NaN     NaN         NaN        NaN
# 25722          xx          NaN     NaN         NaN        NaN
#
#                   Area                        Location     Activity  \
# 0           California     Oceanside, San Diego County     Paddling
# 1              Georgia  St. Simon Island, Glynn County     Standing
# ...

# %%
print(df.head())
# Out:
#   Case Number         Date    Year        Type    Country             Area  \
# 0  2018.06.25  25-Jun-2018  2018.0     Boating        USA       California
# 1  2018.06.18  18-Jun-2018  2018.0  Unprovoked        USA          Georgia
# 2  2018.06.09  09-Jun-2018  2018.0     Invalid        USA           Hawaii
# 3  2018.06.08  08-Jun-2018  2018.0  Unprovoked  AUSTRALIA  New South Wales
# 4  2018.06.04  04-Jun-2018  2018.0    Provoked     MEXICO           Colima
#
#                          Location     Activity             Name Sex   ...  \
# 0     Oceanside, San Diego County     Paddling      Julie Wolfe    F  ...
# 1  St. Simon Island, Glynn County     Standing  Adyson McNeely     F  ...
# 2                    Habush, Oahu      Surfing      John Denges    M  ...
# 3              Arrawarra Headland      Surfing             male    M  ...
# 4                        La Ticla  Free diving   Gustavo Ramos     M  ...
#
# ...

# %%
df = df.drop('href', axis=1)
df
# Out:
#       Case Number         Date    Year        Type    Country  \
# 0      2018.06.25  25-Jun-2018  2018.0     Boating        USA
# 1      2018.06.18  18-Jun-2018  2018.0  Unprovoked        USA
# 2      2018.06.09  09-Jun-2018  2018.0     Invalid        USA
# 3      2018.06.08  08-Jun-2018  2018.0  Unprovoked  AUSTRALIA
# 4      2018.06.04  04-Jun-2018  2018.0    Provoked     MEXICO
# ...           ...          ...     ...         ...        ...
# 6307            0          NaN     NaN         NaN        NaN
# 6308            0          NaN     NaN         NaN        NaN
# 6309            0          NaN     NaN         NaN        NaN
# 8702          NaN          NaN     NaN         NaN        NaN
# 25722          xx          NaN     NaN         NaN        NaN
#
#                   Area                        Location     Activity  \
# 0           California     Oceanside, San Diego County     Paddling
# 1              Georgia  St. Simon Island, Glynn County     Standing
# ...

# %%
df = df.drop('href formula', axis=1)
df
# Out:
#       Case Number         Date    Year        Type    Country  \
# 0      2018.06.25  25-Jun-2018  2018.0     Boating        USA
# 1      2018.06.18  18-Jun-2018  2018.0  Unprovoked        USA
# 2      2018.06.09  09-Jun-2018  2018.0     Invalid        USA
# 3      2018.06.08  08-Jun-2018  2018.0  Unprovoked  AUSTRALIA
# 4      2018.06.04  04-Jun-2018  2018.0    Provoked     MEXICO
# ...           ...          ...     ...         ...        ...
# 6307            0          NaN     NaN         NaN        NaN
# 6308            0          NaN     NaN         NaN        NaN
# 6309            0          NaN     NaN         NaN        NaN
# 8702          NaN          NaN     NaN         NaN        NaN
# 25722          xx          NaN     NaN         NaN        NaN
#
#                   Area                        Location     Activity  \
# 0           California     Oceanside, San Diego County     Paddling
# 1              Georgia  St. Simon Island, Glynn County     Standing
# ...

# %%
df.dropna(inplace=True)

# %%
df
# Out:
#        Case Number         Date    Year        Type    Country          Area  \
# 0       2018.06.25  25-Jun-2018  2018.0     Boating        USA    California
# 6     2018.06.03.a  03-Jun-2018  2018.0  Unprovoked     BRAZIL    Pernambuco
# 8     2018.05.26.b  26-May-2018  2018.0  Unprovoked        USA       Florida
# 10      2018.05.24  24-May-2018  2018.0    Provoked  AUSTRALIA    Queensland
# 13    2018.05.13.a  13-May-2018  2018.0     Invalid    ENGLAND      Cornwall
# ...            ...          ...     ...         ...        ...           ...
# 5814    1880.11.25  25-Nov-1880  1880.0  Unprovoked  AUSTRALIA    Queensland
# 5922    1868.05.13  13-May-1868  1868.0  Unprovoked      INDIA  Hoogly River
# 6242       ND.0064        1960s  1847.5  Unprovoked       IRAQ        Basrah
# 6243       ND.0063        1960s  1847.5  Unprovoked       IRAQ        Basrah
# 6265       ND.0038    1941-1942  1847.5  Unprovoked       IRAQ        Basrah
#
# ...

# %% [markdown]
# # **Visualisasi**

# %%
country_counts = df['Country'].value_counts().head(10)

# %%
plt.figure(figsize=(12, 6))
sns.barplot(x=country_counts.index, y=country_counts.values, color='purple')
plt.title('Distribusi Serangan Hiu Berdasarkan Negara (Top 10)')
plt.xlabel('Negara')
plt.ylabel('Jumlah Serangan')
plt.xticks(rotation=45, ha='right')
plt.show()

# %%
filtered_df = df[df['Year'] >= 1500]
year_fatal_counts = filtered_df.groupby('Year')['Fatal (Y/N)'].value_counts().unstack(fill_value=0)
plt.figure(figsize=(12, 6))
sns.scatterplot(x=year_fatal_counts.index, y=year_fatal_counts['Y'], color='purple', alpha=0.5)
plt.title('Hubungan antara Fatalitas dan Tahun (Mulai Tahun 1500)')
plt.xlabel('Tahun')
plt.ylabel('Jumlah Fatalitas')
plt.xticks(rotation=45, ha='right')
plt.xlim(1500, df['Year'].max())
plt.show()

# %%
location_stats = df.groupby('Area').agg(
    serangan_per_negara=('Case Number', 'count'),
    persentase_serangan_fatal=('Fatal (Y/N)', lambda x: (x == 'Y').mean() * 100)
).reset_index()
top_locations = location_stats.nlargest(10, 'serangan_per_negara')
top_locations.set_index('Area')[['serangan_per_negara', 'persentase_serangan_fatal']].plot(kind='bar')
plt.title('Perbandingan Jumlah Serangan vs Rata-rata Tingkat Keparahan Cedera')
plt.ylabel('Jumlah / Tingkat Keparahan')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# # **Insight Dari Visualisasi Data Serangan Hiu**

# %% [markdown]
# **1. Distribusi Serangan Hiu Berdasarkan Negara**
#
# Sebagian besar serangan hiu terkonsentrasi di beberapa negara, seperti Amerika Serikat dan Australia. Hal ini menunjukkan bahwa negara-negara tersebut mempunyai perairan yang lebih sering dikunjungi hiu atau memiliki aktivitas manusia di laut yang lebih tinggi. Ada beberapa negara dengan jumlah serangan yang relatif rendah, menunjukkan risiko yang lebih kecil di wilayah tersebut.
#
# **2. Hubungan antara Fatalitas dan Tahun**
#
# Secara umum, ada tren peningkatan jumlah serangan hiu yang fatal seiring berjalannya waktu, khususnya sejak tahun 1900-an. Ini kemungkinan disebabkan oleh peningkatan aktivitas manusia di laut, perubahan iklim, atau faktor lainnya. Namun, perlu diingat bahwa data serangan hiu di masa lampau mungkin kurang lengkap.
#
# **3. Perbandingan Jumlah Serangan dan Tingkat Keparahan di Berbagai Lokasi**
#
# Beberapa lokasi memiliki jumlah serangan hiu yang tinggi dengan persentase fatalitas yang tinggi juga, menunjukkan bahwa area tersebut berisiko tinggi. Lokasi lain mungkin memiliki jumlah serangan yang tinggi tetapi persentase fatalitas yang rendah, menunjukkan bahwa serangan di area tersebut cenderung tidak fatal.

# %% [markdown]
# # **Tindakan Yang Bisa Diambil**

# %% [markdown]
# **Untuk Otoritas kelautan & Penjaga Pantai**
#
# Perlu untuk fokus pada lokasi yang memiliki risiko tinggi, seperi pasang rambu peringatan, dan juga edukasi masyarakat, agar masyarakat bisa tahu tentang keselamatan di lokasi dengan jumlah serangan dan fatalitas tinggi. Selanjutnya, perlu untuk teliti penyebab peningkatan serangan. Agar dapat memahami faktor-faktor yang berkontribusi pada peningkatan serangan hiu, sepertivperubahan iklim, pergeseran populasi hiu, atau aktivitas manusia.
#
# **Untuk Masyarakat dan Wisatawan**
#
# Para pengunjung perlu berhati-hati seperti menghindari lokasi berisiko tinggi, edukasi diri tentang keselamatan dari serangan hiu, ikuti panduan keselamatan dari para otoritas kelautan dan penjaga pantai, dan juga melaporkan bila ada melihat penampakan hiu.
